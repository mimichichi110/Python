# %%
from tkinter import *
import tkinter.font as tkFont

def mon1():
    bunbo = mon_1.get()*int(sl1.get())
    mon1['text'] = str(bunbo) + "K"

def mon2():
    buncha = mon_2.get()*int(sl2.get())
    mon2['text'] = str(buncha) + "K"

def mon3():
    bundau = mon_3.get()*int(sl3.get())
    mon3['text'] = str(bundau) + "K"
    
def mon4():
    trada = mon_4.get()*int(sl4.get())
    mon4['text'] = str(trada) + "K"

def total_BF():
    discount = int(payvar.get())/100
    totalBF['text'] = mon_1.get()*int(sl1.get()) + mon_2.get()*int(sl2.get()) + mon_3.get()*int(sl3.get()) + mon_4.get()*int(sl4.get())
    totalBF['text'] = str(int(round(int(totalBF['text'])*discount,0))) + "K"
    
    
root = Tk()
root.geometry("500x500")

menu_name = Label(root, text='Quán gì đó',)
menu_name.place(x=180,y=10)
Font_tuple = ("Comic Sans MS", 20, "bold")
menu_name.configure(font = Font_tuple)

menu = LabelFrame(root, width = 450, height = 200, text = "Menu", font=("Times",13,'bold'))
menu.place(x=10,y=50)

food = Label(menu, anchor = W, text='Món ăn', font=("Times",12,'bold'))
price = Label(menu,text='Đơn giá', font=("Times",12,'bold'))
amount = Label(menu,text='Số lượng', font=("Times",12,'bold'))
thanhtien = Label(menu,text='Thành tiền', font=("Times",12,'bold'))
food.place(x=4,y=5)
price.place(x=130,y=5)
amount.place(x=210,y=5)
thanhtien.place(x=300,y=5)

#ds món ăn
mon_1 = IntVar()
mon_2 = IntVar()
mon_3 = IntVar()
mon_4 = IntVar()
C1 = Checkbutton(menu, anchor = W, text = 'Bún bò',variable = mon_1,onvalue=55, offvalue=0,height=2,width=20,command=mon1)
C2 = Checkbutton(menu, anchor = W, text = 'Bún chả',variable = mon_2,onvalue=65, offvalue=0,height=2,width=20,command=mon2)
C3 = Checkbutton(menu, anchor = W, text = 'Bún đậu',variable = mon_3,onvalue=50, offvalue=0,height=2,width=20,command=mon3)
C4 = Checkbutton(menu, anchor = W, text = 'Trà đá',variable = mon_4,onvalue=10, offvalue=0,height=2,width=20,command=mon4)
C1.place(x=10,y=35)
C2.place(x=10,y=65)
C3.place(x=10,y=95)
C4.place(x=10,y=125)

#2nd giá tiền
p1 = Label(menu,text="55K/phần")
p2 = Label(menu,text="65K/phần")
p3 = Label(menu,text="50K/phần")
p4 = Label(menu,text="10K/ly")
p1.place(x=130,y=43)
p2.place(x=130,y=73)
p3.place(x=130,y=103)
p4.place(x=130,y=133)

#3rd so luong
sl1 = Entry(menu,text="")
sl2 = Entry(menu,text="")
sl3 = Entry(menu,text="")
sl4 = Entry(menu,text="")
sl1.bind('<Leave>',mon1)
sl2.bind('<Leave>',mon2)
sl3.bind('<Leave>',mon3)
sl4.bind('<Leave>',mon4)
sl1.place(x=230,y=43,width=30)
sl2.place(x=230,y=73,width=30)
sl3.place(x=230,y=103,width=30)
sl4.place(x=230,y=133,width=30)

# Thành tiền
mon1 = Label(menu, text="")
mon2 = Label(menu, text="")
mon3 = Label(menu, text="")
mon4 = Label(menu, text="")
mon1.place(x=320,y=43)
mon2.place(x=320,y=73)
mon3.place(x=320,y=103)
mon4.place(x=320,y=133)

#Payment method
payment = LabelFrame(root, width = 450, height = 80, text = "Hình thức thanh toán", font=("Times",15))
payment.place(x=10,y=250)

payvar = IntVar()

cash = Radiobutton(payment, text = "Tiền mặt(-5%)", variable=payvar, value = 95, command=selected)
intbank = Radiobutton(payment, text = "Chuyển khoản(+5%)", variable=payvar, value = 105, command=selected)
cash.place(x=12,y=10)
intbank.place(x=200,y=10)

#Payment
total = LabelFrame(root, width = 450, height = 150, text = "Thanh toán", font=("Times",15))
total.place(x=10,y=330)

total_BF = Label(total, text = 'Tổng số tiền:', font=("Times",12)).place(x=10,y=10)
discount = Label(total, text = 'Giảm giá:', font=("Times",12)).place(x=10,y=40)
total_AF = Label(total, text = 'Tổng số tiền cần thanh toán:', font=("Times",12)).place(x=10,y=70)

totalBF = Label(total, text='0', font=("Times",12))
totalBF.place(x=120,y=10)

label = Label(root, text="")
label.pack()
root.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\chaul\Anaconda3\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
# TypeError: mon1() takes 0 positional arguments but 1 was given
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\chaul\Anaconda3\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
# TypeError: mon4() takes 0 positional arguments but 1 was given
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\chaul\Anaconda3\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "<ipython-input-20-ea94512e955e>", line 21, in selected
#     val = mon_1.get()*int(sl1.get()) + mon_2.get()*int(sl2.get()) + mon_3.get()*int(sl3.get()) + mon_4.get()*int(sl4.get())
# ValueError: invalid literal for int() with base 10: ''
